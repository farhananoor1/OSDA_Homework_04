# %%
import fcalc
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Binarized data

# %%
column_names = [
        'top-left-square', 'top-middle-square', 'top-right-square',
        'middle-left-square', 'middle-middle-square', 'middle-right-square',
        'bottom-left-square', 'bottom-middle-square', 'bottom-right-square',
        'Class'
    ]
df = pd.read_csv('data_sets/tic-tac-toe.data', names = column_names)
df['Class'] = [x == 'positive' for x in df['Class']]
df.sample(10)
# Out:
#     top-left-square top-middle-square top-right-square middle-left-square  \
# 483               o                 b                b                  b
# 833               o                 o                o                  o
# 574               b                 o                o                  b
# 239               x                 b                o                  x
# 320               o                 x                o                  x
# 491               b                 x                x                  o
# 281               x                 b                b                  x
# 385               o                 o                x                  o
# 291               x                 b                b                  o
# 913               b                 x                b                  b
#
#     middle-middle-square middle-right-square bottom-left-square  \
# 483                    b                   o                  x
# 833                    x                   x                  x
# 574                    o                   x                  x
# 239                    x                   x                  o
# 320                    x                   x                  o
# 491                    o                   x                  b
# 281                    o                   b                  x
# 385                    x                   o                  x
# 291                    x                   b                  b
# 913                    x                   x                  o
#
#     bottom-middle-square bottom-right-square  Class
# 483                    x                   x   True
# 833                    b                   x  False
# 574                    x                   x   True
# 239                    o                   b   True
# 320                    o                   x   True
# 491                    o                   x   True
# 281                    o                   b   True
# 385                    x                   x   True
# 291                    o                   x   True
# 913                    o                   o  False

# %%
X = pd.get_dummies(df[column_names[:-1]], prefix=column_names[:-1]).astype(bool)
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
bin_cls = fcalc.classifier.BinarizedBinaryClassifier(X_train.values, y_train.to_numpy(), method="standard-support")

# %%
bin_cls.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score, f1_score

print(accuracy_score(y_test, bin_cls.predictions))
print(f1_score(y_test, bin_cls.predictions))
# Out:
# 0.9965277777777778
# 0.9974160206718347

# %% [markdown]
# # Pattern structures

# %%
column_names = [
        'top-left-square', 'top-middle-square', 'top-right-square',
        'middle-left-square', 'middle-middle-square', 'middle-right-square',
        'bottom-left-square', 'bottom-middle-square', 'bottom-right-square',
        'Class'
    ]
df = pd.read_csv('data_sets/tic-tac-toe.data', names = column_names)
df['Class'] = [x == 'positive' for x in df['Class']]
df.head()
# Out:
#   top-left-square top-middle-square top-right-square middle-left-square  \
# 0               x                 x                x                  x
# 1               x                 x                x                  x
# 2               x                 x                x                  x
# 3               x                 x                x                  x
# 4               x                 x                x                  x
#
#   middle-middle-square middle-right-square bottom-left-square  \
# 0                    o                   o                  x
# 1                    o                   o                  o
# 2                    o                   o                  o
# 3                    o                   o                  o
# 4                    o                   o                  b
#
#   bottom-middle-square bottom-right-square  Class
# 0                    o                   o   True
# 1                    x                   o   True
# 2                    o                   x   True
# 3                    b                   b   True
# 4                    o                   b   True

# %%
X = df[column_names[:-1]]
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pat_cls = fcalc.classifier.PatternBinaryClassifier(X_train.values, y_train.to_numpy(), 
                                             categorical=np.arange(X_train.shape[1]))

# %%
pat_cls.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score, f1_score

print(accuracy_score(y_test, pat_cls.predictions))
print(f1_score(y_test, pat_cls.predictions))
# Out:
# 0.9930555555555556
# 0.9948453608247423

# %%
df = pd.read_csv('data_sets/iris.data', names=['sepal_length',	'sepal_width',	'petal_length',	'petal_width','species'])
df['species'] = [x == 'Iris-setosa' for x in df['species']]
df.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 75            6.6          3.0           4.4          1.4    False
# 102           7.1          3.0           5.9          2.1    False
# 61            5.9          3.0           4.2          1.5    False
# 149           5.9          3.0           5.1          1.8    False
# 40            5.0          3.5           1.3          0.3     True
# 69            5.6          2.5           3.9          1.1    False
# 147           6.5          3.0           5.2          2.0    False
# 68            6.2          2.2           4.5          1.5    False
# 129           7.2          3.0           5.8          1.6    False
# 84            5.4          3.0           4.5          1.5    False

# %%
X = df.iloc[:,:-1]
y = df['species']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pat_cls = fcalc.classifier.PatternBinaryClassifier(X_train.values, y_train.to_numpy())

# %%
pat_cls.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score, f1_score
print("accuracy:",round(accuracy_score(y_test, pat_cls.predictions),4))
print("f1 score:",round(f1_score(y_test, pat_cls.predictions),4))
# Out:
# accuracy: 1.0
# f1 score: 1.0

# %%
df = pd.read_csv('data_sets/heart_failure_clinical_records_dataset.csv')
df.sample(5)
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 6    75.0        1                       246         0                 15
# 138  62.0        0                       281         1                 35
# 81   67.0        0                       582         0                 50
# 86   55.0        0                        47         0                 35
# 162  63.0        1                       582         0                 40
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 6                      0  127000.00              1.20           137    1
# 138                    0  221000.00              1.00           136    0
# 81                     0  263358.03              1.18           137    1
# 86                     1  173000.00              1.10           137    1
# 162                    0  448000.00              0.90           137    1
#
#      smoking  time  DEATH_EVENT
# 6          0    10            1
# 138        0   108            0
# 81         1    76            0
# 86         0    79            0
# 162        1   123            0

# %%
X = df.iloc[:,:-1]
y = df['DEATH_EVENT']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
pat_cls = fcalc.classifier.PatternBinaryClassifier(X_train.values, y_train.to_numpy(), 
                                                   categorical=np.array([1,3,5,9,10]))

# %%
pat_cls.predict(X_test.values)

# %%
from sklearn.metrics import accuracy_score, f1_score
print("accuracy:",round(accuracy_score(y_test, pat_cls.predictions),4))
print("f1 score:",round(f1_score(y_test, pat_cls.predictions),4))
# Out:
# accuracy: 0.6778
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 3
#       1 from sklearn.metrics import accuracy_score, f1_score
#       2 print("accuracy:",round(accuracy_score(y_test, pat_cls.predictions),4))
# ----> 3 print("f1 score:",round(f1_score(y_test, pat_cls.predictions),4))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1239, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1070 @validate_params(
#    1071     {
#    1072         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1097     zero_division="warn",
#    1098 ):
#    1099     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1100
#    1101     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1237     array([0.66666667, 1.        , 0.66666667])
#    1238     """
# -> 1239     return fbeta_score(
#    1240         y_true,
#    1241         y_pred,
#    1242         beta=1,
#    1243         labels=labels,
#    1244         pos_label=pos_label,
#    1245         average=average,
#    1246         sample_weight=sample_weight,
#    1247         zero_division=zero_division,
#    1248     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1413, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1251 @validate_params(
#    1252     {
#    1253         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1280     zero_division="warn",
#    1281 ):
#    1282     """Compute the F-beta score.
#    1283
#    1284     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1410     0.38...
#    1411     """
# -> 1413     _, _, f, _ = precision_recall_fscore_support(
#    1414         y_true,
#    1415         y_pred,
#    1416         beta=beta,
#    1417         labels=labels,
#    1418         pos_label=pos_label,
#    1419         average=average,
#    1420         warn_for=("f-score",),
#    1421         sample_weight=sample_weight,
#    1422         zero_division=zero_division,
#    1423     )
#    1424     return f
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1724, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1566 """Compute precision, recall, F-measure and support for each class.
#    1567
#    1568 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1721  array([2, 2, 2]))
#    1722 """
#    1723 zero_division_value = _check_zero_division(zero_division)
# -> 1724 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1726 # Calculate tp_sum, pred_sum, true_sum ###
#    1727 samplewise = average == "samples"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\metrics\_classification.py:1518, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1516         if y_type == "multiclass":
#    1517             average_options.remove("samples")
# -> 1518         raise ValueError(
#    1519             "Target is %s but average='binary'. Please "
#    1520             "choose another average setting, one of %r." % (y_type, average_options)
#    1521         )
#    1522 elif pos_label not in (None, 1):
#    1523     warnings.warn(
#    1524         "Note that pos_label (set to %r) is ignored when "
#    1525         "average != 'binary' (got %r). You may use "
#    (...)
#    1528         UserWarning,
#    1529     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].
